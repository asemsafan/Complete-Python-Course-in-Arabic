# %% [markdown]
# <a href='https://www.youtube.com/playlist?list=PLMDrOnfT8EAgCPrFfF8OgMQOTtMUk78AJ'><img src='../course_img.png'/></a>

# %% [markdown]
# # Modules and Packages

# %% [markdown]
# #### Module

# %%
import mymodule

# %%
mymodule.func1()
# Out:
# I am a function in myModule.py file

# %% [markdown]
# #### Packages

# %%
from MyPackage import main_script

# %%
main_script.main_func()
# Out:
# I am a function in main file in the package

# %%
from MyPackage.SubPackage import sub_script

# %%
sub_script.sub_func ()
# Out:
# I am a function in subscript file in the sub package
